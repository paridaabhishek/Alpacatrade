# %% [markdown]
# <a href="https://colab.research.google.com/github/paridaabhishek/Alpacatrade/blob/master/5MinsWithTimeZoneLivewith921EMAProcess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install WebSocket
# !pip install websocket-client
# !pip install alpaca-trade-api
# Out:
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.7/dist-packages (1.2.3)
# Requirement already satisfied: alpaca-trade-api in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (1.21.5)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (2.23.0)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (1.24.3)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (1.3.5)
# Requirement already satisfied: websockets<10,>=8.0 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (9.1)
# Requirement already satisfied: aiohttp==3.7.4 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (3.7.4)
# Requirement already satisfied: msgpack==1.0.2 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (1.0.2)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (1.2.3)
# Requirement already satisfied: PyYAML==5.4.1 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (5.4.1)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (2.1.0)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca-trade-api) (3.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca-trade-api) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca-trade-api) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca-trade-api) (3.10.0.2)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca-trade-api) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca-trade-api) (1.7.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation==2.1.0->alpaca-trade-api) (21.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18.1->alpaca-trade-api) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>2->alpaca-trade-api) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>2->alpaca-trade-api) (2.10)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->deprecation==2.1.0->alpaca-trade-api) (3.0.7)

# %%
#Import Libreris
import websocket 
import json
from datetime import datetime
import pandas as pd
import numpy as np
from IPython.core.display import JSON
import pytz
from datetime import datetime
from datetime import timedelta

# %%
#Map Google drive
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
ticket_interested = (input('Enter The Stock yo wanted to autotrade')).upper()
print(ticket_interested+ ' Will be autotraded now!! Sitback and enjoy your day!!')

listen_message='{"action":"subscribe","bars":["'+ticket_interested+'"]}'
print(listen_message)
# Out:
# Enter The Stock yo wanted to autotradeNkla
# NKLA Will be autotraded now!! Sitback and enjoy your day!!
# {"action":"subscribe","bars":["NKLA"]}

# %%
#Import Credentials. Kept the credential in the file Cred.py under the dir below for security.
import sys
import os
import glob
print(glob.glob("/content/drive/*"))
os.chdir('/content/drive//MyDrive/AlpecaTrading/Config')
#sys.path.append('/content/drive/AlpecaTrading/Config')
print(os.getcwd())
from  Cred import *
# Out:
# ['/content/drive/MyDrive']
# /content/drive/MyDrive/AlpecaTrading/Config

# %%
#Websocket Code
socket = "wss://stream.data.alpaca.markets/v2/sip" #Webscoket given by alpeca for 
#socket = "wss://paper-api.alpaca.markets/stream" #Webscoket given by alpeca for 
#socket = "wss://stream.data.alpaca.markets/v1beta1/crypto"

print(socket.split('/')[-1])

def on_ope_fun(ws):
    print("Opened")
    auth_data = {"action": "auth","key": API_KEY,"secret": SECRET_KEY }  #Key and Secret getting from the Cred file. 
    ws.send(json.dumps(auth_data))
    #listen_message={"action":"subscribe","trades":["BTCUSD"],"quotes":["LTCUSD","ETHUSD"],"bars":["BCHUSD"]}
    #listen_message={"action":"subscribe","trades":["BTCUSD"]}
    #listen_message={"action":"subscribe","bars":["BTCUSD"]}
    listen_message='{"action":"subscribe","bars":["'+ticket_interested+'"]}'
    #print(listen_message)
    #listen_message={"action":"subscribe","bars":["AAPL"]}  ### --> Modify based on whatever symbol you want to check
    ws.send(json.dumps(json.loads(listen_message)))


    print('Still Open')

def on_msg_fun(ws,message):
    now = datetime.now()
    current_time = now.strftime("%H:%M:%S")
    print("messgae received at"+ current_time)
    print(message)
    print('Strated wring to the steam file')
    OnetoFiveMinLive(message)
    print('Wrttin  steam file')

def on_clg_fun(ws):
    print("Closed")
# Out:
# sip

# %%
def OnetoFiveMinLive(message):
  try:

    #######################Create a file which will hold the stream data based on the ticker name ########################################################
    messageJson = json.loads(message)
    df = pd.DataFrame(messageJson)
    df.to_csv('/content/drive//MyDrive/AlpecaTrading/DataFiles/StreamFiles/{}.csv'.format(ticket_interested),mode='a', index=False, header=False)

    with open('/content/drive//MyDrive/AlpecaTrading/DataFiles/StreamFiles/{}.csv'.format(ticket_interested), 'r') as fp:
      for count, line in enumerate(fp):
        pass
      total_lines =count+1


    print('Total Lines in the Strimming file'+str(total_lines))

    if total_lines <= 10 :
       print('As we less than 10 and is :'+str(total_lines)+'. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....')


    if total_lines > 10:

      print('As we have 10 datapoints the calucation for 1 to 5 mins conversion started....')
      df = pd.read_csv('/content/drive//MyDrive/AlpecaTrading/DataFiles/StreamFiles/{}.csv'.format(ticket_interested),skiprows=3,header=None,index_col=False)
      df.columns =['Message Type', 
                'Symbol', 
                'Open', 
                'Close',
                'High',
                'Low',
                'Volume',
                'TimeStamp',
                'n',
                'vw']
      df_unique=df.drop_duplicates(subset=['TimeStamp']).copy()
      df_unique.loc[:,'TimeStamp'] = pd.to_datetime(df_unique['TimeStamp'])
      df_unique.set_index('TimeStamp',inplace=True)
      print('Total Lines in the unique file is :'+ str(len(df_unique.index)))

      #Convert the UTC timeZone to easter timezone
      eastern = pytz.timezone('US/Central')
      df_unique.index = df_unique.index.tz_convert(eastern)
      df_unique.to_csv('/content/drive//MyDrive/AlpecaTrading/DataFiles/BarFiles/{}_1MinsBar.csv'.format(ticket_interested),mode='w', index=True, header=True)


      df_unique['5MinReminder'] = df_unique.index.minute % 5
      df_unique['15MinReminder'] = df_unique.index.minute % 15 #incase want to code for 15 mins bars

      min_time=df_unique[df_unique['5MinReminder']==0].index.min() #gets min time time where the 5 mins remider is zero. We need the data from next minute
      start_time = min_time + timedelta(minutes=1) # first pointer from where the 5 mins bar will start


      df_unique_start=df_unique.loc[start_time:].copy()

      df_5mins_bar=df_unique_start.groupby(pd.Grouper(freq='5min')).agg({'Open':'first',
                                                       'Close':'last',
                                                       'High':'max',
                                                       'Low':'min'}).iloc[1:]
      df_5mins_bar['9EMAClosed']  = df_unique['Close'].ewm(span=9,adjust=True).mean()
      df_5mins_bar['21EMAClosed'] = df_unique['Close'].ewm(span=21,adjust=True).mean()
      
      
      df_5mins_bar.to_csv('/content/drive//MyDrive/AlpecaTrading/DataFiles/BarFiles/{}_5MinsBar.csv'.format(ticket_interested),mode='w', index=True, header=True)
      print(df_5mins_bar)

     









  except Exception as ex:
    print(ex)

# %%
ws = websocket.WebSocketApp(socket, on_open=on_ope_fun,on_message=on_msg_fun)
ws.run_forever()
# Out:
# Opened
# Still Open
# messgae received at20:11:59
# [{"T":"success","msg":"connected"}]
# Strated wring to the steam file
# Total Lines in the Strimming file1
# As we less than 10 and is :1. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....
# Wrttin  steam file
# messgae received at20:11:59
# [{"T":"success","msg":"authenticated"}]
# Strated wring to the steam file
# Total Lines in the Strimming file2
# As we less than 10 and is :2. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....
# Wrttin  steam file
# messgae received at20:11:59
# [{"T":"subscription","trades":[],"quotes":[],"bars":["NKLA"],"dailyBars":[],"statuses":[],"lulds":[],"corrections":[],"cancelErrors":[]}]
# Strated wring to the steam file
# Total Lines in the Strimming file3
# As we less than 10 and is :3. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....
# Wrttin  steam file
# messgae received at20:12:00
# [{"T":"b","S":"NKLA","o":8.075,"c":8.085,"h":8.09,"l":8.075,"v":12211,"t":"2022-02-17T20:11:00Z","n":91,"vw":8.084506}]
# Strated wring to the steam file
# Total Lines in the Strimming file4
# As we less than 10 and is :4. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....
# Wrttin  steam file
# messgae received at20:13:00
# [{"T":"b","S":"NKLA","o":8.085,"c":8.0784,"h":8.085,"l":8.07,"v":19118,"t":"2022-02-17T20:12:00Z","n":79,"vw":8.07494}]
# Strated wring to the steam file
# Total Lines in the Strimming file5
# As we less than 10 and is :5. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....
# Wrttin  steam file
# messgae received at20:14:00
# [{"T":"b","S":"NKLA","o":8.075,"c":8.07,"h":8.08,"l":8.07,"v":25596,"t":"2022-02-17T20:13:00Z","n":90,"vw":8.076327}]
# Strated wring to the steam file
# Total Lines in the Strimming file6
# As we less than 10 and is :6. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....
# Wrttin  steam file
# messgae received at20:15:00
# [{"T":"b","S":"NKLA","o":8.07,"c":8.065,"h":8.08,"l":8.06,"v":38197,"t":"2022-02-17T20:14:00Z","n":220,"vw":8.067562}]
# Strated wring to the steam file
# Total Lines in the Strimming file7
# As we less than 10 and is :7. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....
# Wrttin  steam file
# messgae received at20:16:00
# [{"T":"b","S":"NKLA","o":8.0695,"c":8.08,"h":8.085,"l":8.063,"v":27852,"t":"2022-02-17T20:15:00Z","n":179,"vw":8.074744}]
# Strated wring to the steam file
# Total Lines in the Strimming file8
# As we less than 10 and is :8. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....
# Wrttin  steam file
# messgae received at20:17:00
# [{"T":"b","S":"NKLA","o":8.085,"c":8.07,"h":8.0874,"l":8.065,"v":24349,"t":"2022-02-17T20:16:00Z","n":130,"vw":8.073518}]
# Strated wring to the steam file
# Total Lines in the Strimming file9
# As we less than 10 and is :9. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....
# Wrttin  steam file
# messgae received at20:18:00
# [{"T":"b","S":"NKLA","o":8.075,"c":8.089,"h":8.09,"l":8.07,"v":9688,"t":"2022-02-17T20:17:00Z","n":73,"vw":8.081803}]
# Strated wring to the steam file
# Total Lines in the Strimming file10
# As we less than 10 and is :10. datapoints 1 to 5 mins bar calucation will be skipped till we have 10 points ....
# Wrttin  steam file
# messgae received at20:19:00
# [{"T":"b","S":"NKLA","o":8.09,"c":8.065,"h":8.09,"l":8.05,"v":62575,"t":"2022-02-17T20:18:00Z","n":282,"vw":8.071477}]
# Strated wring to the steam file
# Total Lines in the Strimming file11
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :8
#                            Open  Close  High  Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:11:00-06:00   NaN    NaN   NaN  NaN    8.085000     8.085000
# 2022-02-17 14:12:00-06:00   NaN    NaN   NaN  NaN    8.081333     8.081543
# 2022-02-17 14:13:00-06:00   NaN    NaN   NaN  NaN    8.076689     8.077323
# 2022-02-17 14:14:00-06:00   NaN    NaN   NaN  NaN    8.072729     8.073789
# 2022-02-17 14:15:00-06:00   NaN    NaN   NaN  NaN    8.074892     8.075279
# 2022-02-17 14:16:00-06:00   NaN    NaN   NaN  NaN    8.073566     8.074177
# 2022-02-17 14:17:00-06:00   NaN    NaN   NaN  NaN    8.077472     8.076945
# 2022-02-17 14:18:00-06:00   NaN    NaN   NaN  NaN    8.074475     8.074909
# Wrttin  steam file
# messgae received at20:20:00
# [{"T":"b","S":"NKLA","o":8.065,"c":8.0766,"h":8.08,"l":8.055,"v":63490,"t":"2022-02-17T20:19:00Z","n":165,"vw":8.072677}]
# Strated wring to the steam file
# Total Lines in the Strimming file12
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :9
#                            Open  Close  High  Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:11:00-06:00   NaN    NaN   NaN  NaN    8.085000     8.085000
# 2022-02-17 14:12:00-06:00   NaN    NaN   NaN  NaN    8.081333     8.081543
# 2022-02-17 14:13:00-06:00   NaN    NaN   NaN  NaN    8.076689     8.077323
# 2022-02-17 14:14:00-06:00   NaN    NaN   NaN  NaN    8.072729     8.073789
# 2022-02-17 14:15:00-06:00   NaN    NaN   NaN  NaN    8.074892     8.075279
# 2022-02-17 14:16:00-06:00   NaN    NaN   NaN  NaN    8.073566     8.074177
# 2022-02-17 14:17:00-06:00   NaN    NaN   NaN  NaN    8.077472     8.076945
# 2022-02-17 14:18:00-06:00   NaN    NaN   NaN  NaN    8.074475     8.074909
# 2022-02-17 14:19:00-06:00   NaN    NaN   NaN  NaN    8.074966     8.075176
# Wrttin  steam file
# messgae received at20:21:00
# [{"T":"b","S":"NKLA","o":8.075,"c":8.0999,"h":8.11,"l":8.07,"v":164175,"t":"2022-02-17T20:20:00Z","n":384,"vw":8.08729}]
# Strated wring to the steam file
# Total Lines in the Strimming file13
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :10
#                             Open   Close  High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.0999  8.11  8.07    8.080552     8.078834
# Wrttin  steam file
# messgae received at20:22:00
# [{"T":"b","S":"NKLA","o":8.095,"c":8.095,"h":8.1,"l":8.085,"v":56346,"t":"2022-02-17T20:21:00Z","n":249,"vw":8.090722}]
# Strated wring to the steam file
# Total Lines in the Strimming file14
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :11
#                             Open  Close  High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.095  8.11  8.07    8.080552     8.078834
# Wrttin  steam file
# messgae received at20:23:00
# [{"T":"b","S":"NKLA","o":8.09,"c":8.1023,"h":8.12,"l":8.09,"v":51715,"t":"2022-02-17T20:22:00Z","n":282,"vw":8.103144}]
# Strated wring to the steam file
# Total Lines in the Strimming file15
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :12
#                             Open   Close  High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.1023  8.12  8.07    8.080552     8.078834
# Wrttin  steam file
# messgae received at20:24:00
# [{"T":"b","S":"NKLA","o":8.1,"c":8.09,"h":8.105,"l":8.085,"v":28819,"t":"2022-02-17T20:23:00Z","n":120,"vw":8.097233}]
# Strated wring to the steam file
# Total Lines in the Strimming file16
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :13
#                             Open  Close  High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075   8.09  8.12  8.07    8.080552     8.078834
# Wrttin  steam file
# messgae received at20:25:00
# [{"T":"b","S":"NKLA","o":8.085,"c":8.085,"h":8.09,"l":8.08,"v":5522,"t":"2022-02-17T20:24:00Z","n":49,"vw":8.08636}]
# Strated wring to the steam file
# Total Lines in the Strimming file17
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :14
#                             Open  Close  High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.12  8.07    8.080552     8.078834
# Wrttin  steam file
# messgae received at20:26:00
# [{"T":"b","S":"NKLA","o":8.085,"c":8.105,"h":8.11,"l":8.085,"v":19790,"t":"2022-02-17T20:25:00Z","n":88,"vw":8.09552}]
# Strated wring to the steam file
# Total Lines in the Strimming file18
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :15
#                             Open  Close  High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.12  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.105  8.11  8.085    8.091146     8.087161
# Wrttin  steam file
# messgae received at20:27:00
# [{"T":"b","S":"NKLA","o":8.1,"c":8.095,"h":8.11,"l":8.095,"v":16523,"t":"2022-02-17T20:26:00Z","n":117,"vw":8.102332}]
# Strated wring to the steam file
# Total Lines in the Strimming file19
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :16
#                             Open  Close  High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.12  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.095  8.11  8.085    8.091146     8.087161
# Wrttin  steam file
# messgae received at20:28:00
# [{"T":"b","S":"NKLA","o":8.095,"c":8.08,"h":8.095,"l":8.08,"v":12546,"t":"2022-02-17T20:27:00Z","n":88,"vw":8.088547}]
# Strated wring to the steam file
# Total Lines in the Strimming file20
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :17
#                             Open  Close  High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.12  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.080  8.11  8.08    8.091146     8.087161
# Wrttin  steam file
# messgae received at20:29:00
# [{"T":"b","S":"NKLA","o":8.08,"c":8.0677,"h":8.08,"l":8.06,"v":24011,"t":"2022-02-17T20:28:00Z","n":105,"vw":8.07358}]
# Strated wring to the steam file
# Total Lines in the Strimming file21
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :18
#                             Open   Close  High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.0850  8.12  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.0677  8.11  8.06    8.091146     8.087161
# Wrttin  steam file
# messgae received at20:30:00
# [{"T":"b","S":"NKLA","o":8.06,"c":8.065,"h":8.07,"l":8.06,"v":9295,"t":"2022-02-17T20:29:00Z","n":56,"vw":8.066536}]
# Strated wring to the steam file
# Total Lines in the Strimming file22
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :19
#                             Open  Close  High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.12  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.11  8.06    8.091146     8.087161
# Wrttin  steam file
# messgae received at20:31:00
# [{"T":"b","S":"NKLA","o":8.065,"c":8.085,"h":8.085,"l":8.065,"v":45936,"t":"2022-02-17T20:30:00Z","n":264,"vw":8.073188}]
# Strated wring to the steam file
# Total Lines in the Strimming file23
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :20
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.085  8.085  8.065    8.081799     8.083059
# Wrttin  steam file
# messgae received at20:32:00
# [{"T":"b","S":"NKLA","o":8.08,"c":8.075,"h":8.08,"l":8.07,"v":12693,"t":"2022-02-17T20:31:00Z","n":61,"vw":8.076557}]
# Strated wring to the steam file
# Total Lines in the Strimming file24
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :21
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.075  8.085  8.065    8.081799     8.083059
# Wrttin  steam file
# messgae received at20:33:00
# [{"T":"b","S":"NKLA","o":8.075,"c":8.06,"h":8.0776,"l":8.055,"v":34972,"t":"2022-02-17T20:32:00Z","n":176,"vw":8.061605}]
# Strated wring to the steam file
# Total Lines in the Strimming file25
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :22
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.060  8.085  8.055    8.081799     8.083059
# Wrttin  steam file
# messgae received at20:34:00
# [{"T":"b","S":"NKLA","o":8.06,"c":8.05,"h":8.06,"l":8.04,"v":37897,"t":"2022-02-17T20:33:00Z","n":268,"vw":8.051042}]
# Strated wring to the steam file
# Total Lines in the Strimming file26
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :23
#                             Open  Close   High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.06    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.04    8.081799     8.083059
# Wrttin  steam file
# messgae received at20:34:30
# [{"T":"b","S":"NKLA","o":8.06,"c":8.05,"h":8.06,"l":8.04,"v":37898,"t":"2022-02-17T20:33:00Z","n":269,"vw":8.051042}]
# Strated wring to the steam file
# Total Lines in the Strimming file27
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :23
#                             Open  Close   High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.06    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.04    8.081799     8.083059
# Wrttin  steam file
# messgae received at20:35:00
# [{"T":"b","S":"NKLA","o":8.0481,"c":8.05,"h":8.05,"l":8.0419,"v":5365,"t":"2022-02-17T20:34:00Z","n":55,"vw":8.047057}]
# Strated wring to the steam file
# Total Lines in the Strimming file28
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :24
#                             Open  Close   High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.06    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.04    8.081799     8.083059
# Wrttin  steam file
# messgae received at20:36:00
# [{"T":"b","S":"NKLA","o":8.045,"c":8.07,"h":8.07,"l":8.04,"v":22808,"t":"2022-02-17T20:35:00Z","n":153,"vw":8.055274}]
# Strated wring to the steam file
# Total Lines in the Strimming file29
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :25
#                             Open  Close   High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.06    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.04    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.070  8.070  8.04    8.067438     8.073718
# Wrttin  steam file
# messgae received at20:37:00
# [{"T":"b","S":"NKLA","o":8.07,"c":8.065,"h":8.07,"l":8.06,"v":12467,"t":"2022-02-17T20:36:00Z","n":89,"vw":8.065801}]
# Strated wring to the steam file
# Total Lines in the Strimming file30
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :26
#                             Open  Close   High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.06    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.04    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.065  8.070  8.04    8.067438     8.073718
# Wrttin  steam file
# messgae received at20:38:00
# [{"T":"b","S":"NKLA","o":8.07,"c":8.08,"h":8.08,"l":8.06,"v":24823,"t":"2022-02-17T20:37:00Z","n":102,"vw":8.072017}]
# Strated wring to the steam file
# Total Lines in the Strimming file31
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :27
#                             Open  Close   High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.06    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.04    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.080  8.080  8.04    8.067438     8.073718
# Wrttin  steam file
# messgae received at20:39:00
# [{"T":"b","S":"NKLA","o":8.08,"c":8.095,"h":8.1,"l":8.075,"v":18257,"t":"2022-02-17T20:38:00Z","n":127,"vw":8.085784}]
# Strated wring to the steam file
# Total Lines in the Strimming file32
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :28
#                             Open  Close   High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.06    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.04    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.095  8.100  8.04    8.067438     8.073718
# Wrttin  steam file
# messgae received at20:40:00
# [{"T":"b","S":"NKLA","o":8.095,"c":8.09,"h":8.11,"l":8.09,"v":19639,"t":"2022-02-17T20:39:00Z","n":129,"vw":8.099074}]
# Strated wring to the steam file
# Total Lines in the Strimming file33
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :29
#                             Open  Close   High   Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.07    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.06    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.04    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.04    8.067438     8.073718
# Wrttin  steam file
# messgae received at20:41:00
# [{"T":"b","S":"NKLA","o":8.095,"c":8.08,"h":8.0999,"l":8.075,"v":16691,"t":"2022-02-17T20:40:00Z","n":98,"vw":8.087219}]
# Strated wring to the steam file
# Total Lines in the Strimming file34
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :30
#                             Open  Close    High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.1200  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.1100  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.0850  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.1100  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.080  8.0999  8.075    8.078188     8.077329
# Wrttin  steam file
# messgae received at20:42:00
# [{"T":"b","S":"NKLA","o":8.075,"c":8.09,"h":8.095,"l":8.075,"v":10708,"t":"2022-02-17T20:41:00Z","n":76,"vw":8.083544}]
# Strated wring to the steam file
# Total Lines in the Strimming file35
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :31
#                             Open  Close    High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.1200  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.1100  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.0850  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.1100  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.090  8.0999  8.075    8.078188     8.077329
# Wrttin  steam file
# messgae received at20:43:00
# [{"T":"b","S":"NKLA","o":8.095,"c":8.0934,"h":8.1,"l":8.09,"v":7312,"t":"2022-02-17T20:42:00Z","n":53,"vw":8.093065}]
# Strated wring to the steam file
# Total Lines in the Strimming file36
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :32
#                             Open   Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.0850  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.0650  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.0500  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.0900  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.0934  8.100  8.075    8.078188     8.077329
# Wrttin  steam file
# messgae received at20:44:00
# [{"T":"b","S":"NKLA","o":8.095,"c":8.115,"h":8.1192,"l":8.095,"v":38643,"t":"2022-02-17T20:43:00Z","n":184,"vw":8.104323}]
# Strated wring to the steam file
# Total Lines in the Strimming file37
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :33
#                             Open  Close    High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.1200  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.1100  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.0850  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.1100  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.1192  8.075    8.078188     8.077329
# Wrttin  steam file
# messgae received at20:45:00
# [{"T":"b","S":"NKLA","o":8.11,"c":8.115,"h":8.12,"l":8.11,"v":15444,"t":"2022-02-17T20:44:00Z","n":82,"vw":8.114888}]
# Strated wring to the steam file
# Total Lines in the Strimming file38
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :34
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# Wrttin  steam file
# messgae received at20:46:00
# [{"T":"b","S":"NKLA","o":8.11,"c":8.12,"h":8.135,"l":8.11,"v":48923,"t":"2022-02-17T20:45:00Z","n":245,"vw":8.126565}]
# Strated wring to the steam file
# Total Lines in the Strimming file39
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :35
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.120  8.135  8.110    8.099686     8.089468
# Wrttin  steam file
# messgae received at20:47:00
# [{"T":"b","S":"NKLA","o":8.11,"c":8.1,"h":8.115,"l":8.085,"v":45646,"t":"2022-02-17T20:46:00Z","n":189,"vw":8.099617}]
# Strated wring to the steam file
# Total Lines in the Strimming file40
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :36
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# Wrttin  steam file
# messgae received at20:48:00
# [{"T":"b","S":"NKLA","o":8.1,"c":8.1,"h":8.11,"l":8.09,"v":15479,"t":"2022-02-17T20:47:00Z","n":99,"vw":8.101989}]
# Strated wring to the steam file
# Total Lines in the Strimming file41
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :37
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# Wrttin  steam file
# messgae received at20:48:30
# [{"T":"b","S":"NKLA","o":8.1,"c":8.1,"h":8.11,"l":8.09,"v":15480,"t":"2022-02-17T20:47:00Z","n":100,"vw":8.101989}]
# Strated wring to the steam file
# Total Lines in the Strimming file42
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :37
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# Wrttin  steam file
# messgae received at20:49:00
# [{"T":"b","S":"NKLA","o":8.105,"c":8.1,"h":8.105,"l":8.0967,"v":17617,"t":"2022-02-17T20:48:00Z","n":101,"vw":8.100713}]
# Strated wring to the steam file
# Total Lines in the Strimming file43
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :38
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# Wrttin  steam file
# messgae received at20:50:00
# [{"T":"b","S":"NKLA","o":8.1,"c":8.1,"h":8.11,"l":8.1,"v":6941,"t":"2022-02-17T20:49:00Z","n":50,"vw":8.105037}]
# Strated wring to the steam file
# Total Lines in the Strimming file44
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :39
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# Wrttin  steam file
# messgae received at20:51:00
# [{"T":"b","S":"NKLA","o":8.1,"c":8.07,"h":8.1,"l":8.06,"v":67634,"t":"2022-02-17T20:50:00Z","n":328,"vw":8.073527}]
# Strated wring to the steam file
# Total Lines in the Strimming file45
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :40
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.070  8.100  8.060    8.093896     8.090762
# Wrttin  steam file
# messgae received at20:52:00
# [{"T":"b","S":"NKLA","o":8.07,"c":8.065,"h":8.08,"l":8.06,"v":27163,"t":"2022-02-17T20:51:00Z","n":90,"vw":8.073702}]
# Strated wring to the steam file
# Total Lines in the Strimming file46
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :41
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.065  8.100  8.060    8.093896     8.090762
# Wrttin  steam file
# messgae received at20:53:00
# [{"T":"b","S":"NKLA","o":8.06,"c":8.065,"h":8.07,"l":8.06,"v":16406,"t":"2022-02-17T20:52:00Z","n":59,"vw":8.063732}]
# Strated wring to the steam file
# Total Lines in the Strimming file47
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :42
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.065  8.100  8.060    8.093896     8.090762
# Wrttin  steam file
# messgae received at20:54:00
# [{"T":"b","S":"NKLA","o":8.06,"c":8.065,"h":8.065,"l":8.05,"v":23368,"t":"2022-02-17T20:53:00Z","n":161,"vw":8.059855}]
# Strated wring to the steam file
# Total Lines in the Strimming file48
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :43
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.065  8.100  8.050    8.093896     8.090762
# Wrttin  steam file
# messgae received at20:55:00
# [{"T":"b","S":"NKLA","o":8.065,"c":8.085,"h":8.085,"l":8.065,"v":25005,"t":"2022-02-17T20:54:00Z","n":203,"vw":8.075246}]
# Strated wring to the steam file
# Total Lines in the Strimming file49
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :44
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# Wrttin  steam file
# messgae received at20:56:00
# [{"T":"b","S":"NKLA","o":8.085,"c":8.11,"h":8.11,"l":8.085,"v":43773,"t":"2022-02-17T20:55:00Z","n":190,"vw":8.104746}]
# Strated wring to the steam file
# Total Lines in the Strimming file50
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :45
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.110  8.110  8.085    8.086668     8.086684
# Wrttin  steam file
# messgae received at20:57:00
# [{"T":"b","S":"NKLA","o":8.11,"c":8.105,"h":8.11,"l":8.1,"v":38926,"t":"2022-02-17T20:56:00Z","n":196,"vw":8.10212}]
# Strated wring to the steam file
# Total Lines in the Strimming file51
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :46
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.105  8.110  8.085    8.086668     8.086684
# Wrttin  steam file
# messgae received at20:58:00
# [{"T":"b","S":"NKLA","o":8.1,"c":8.105,"h":8.11,"l":8.1,"v":17682,"t":"2022-02-17T20:57:00Z","n":93,"vw":8.103243}]
# Strated wring to the steam file
# Total Lines in the Strimming file52
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :47
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.105  8.110  8.085    8.086668     8.086684
# Wrttin  steam file
# messgae received at20:59:00
# [{"T":"b","S":"NKLA","o":8.105,"c":8.095,"h":8.11,"l":8.09,"v":57327,"t":"2022-02-17T20:58:00Z","n":235,"vw":8.099606}]
# Strated wring to the steam file
# Total Lines in the Strimming file53
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :48
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.095  8.110  8.085    8.086668     8.086684
# Wrttin  steam file
# messgae received at21:00:00
# [{"T":"b","S":"NKLA","o":8.09,"c":8.1,"h":8.1,"l":8.09,"v":103682,"t":"2022-02-17T20:59:00Z","n":327,"vw":8.09535}]
# Strated wring to the steam file
# Total Lines in the Strimming file54
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :49
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.100  8.110  8.085    8.086668     8.086684
# Wrttin  steam file
# messgae received at21:00:30
# [{"T":"b","S":"NKLA","o":8.09,"c":8.09,"h":8.1,"l":8.09,"v":103882,"t":"2022-02-17T20:59:00Z","n":328,"vw":8.09534}]
# Strated wring to the steam file
# Total Lines in the Strimming file55
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :49
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.100  8.110  8.085    8.086668     8.086684
# Wrttin  steam file
# messgae received at21:01:00
# [{"T":"b","S":"NKLA","o":8.08,"c":8.1,"h":8.1,"l":8.08,"v":618336,"t":"2022-02-17T21:00:00Z","n":4,"vw":8.080647}]
# Strated wring to the steam file
# Total Lines in the Strimming file56
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :50
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.100  8.110  8.085    8.086668     8.086684
# 2022-02-17 15:00:00-06:00  8.080  8.100  8.100  8.080    8.095913     8.092054
# Wrttin  steam file
# messgae received at21:02:00
# [{"T":"b","S":"NKLA","o":8.08,"c":8.08,"h":8.1,"l":8.07,"v":30722,"t":"2022-02-17T21:01:00Z","n":11,"vw":8.094146}]
# Strated wring to the steam file
# Total Lines in the Strimming file57
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :51
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.100  8.110  8.085    8.086668     8.086684
# 2022-02-17 15:00:00-06:00  8.080  8.080  8.100  8.070    8.095913     8.092054
# Wrttin  steam file
# messgae received at21:04:00
# [{"T":"b","S":"NKLA","o":8.11,"c":8.11,"h":8.11,"l":8.11,"v":201,"t":"2022-02-17T21:03:00Z","n":2,"vw":8.11}]
# Strated wring to the steam file
# Total Lines in the Strimming file58
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :52
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.100  8.110  8.085    8.086668     8.086684
# 2022-02-17 15:00:00-06:00  8.080  8.110  8.110  8.070    8.095913     8.092054
# Wrttin  steam file
# messgae received at21:10:00
# [{"T":"b","S":"NKLA","o":8.08,"c":8.08,"h":8.08,"l":8.08,"v":458,"t":"2022-02-17T21:09:00Z","n":6,"vw":8.08}]
# Strated wring to the steam file
# Total Lines in the Strimming file59
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :53
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.100  8.110  8.085    8.086668     8.086684
# 2022-02-17 15:00:00-06:00  8.080  8.110  8.110  8.070    8.095913     8.092054
# 2022-02-17 15:05:00-06:00  8.080  8.080  8.080  8.080         NaN          NaN
# Wrttin  steam file
# messgae received at21:11:00
# [{"T":"b","S":"NKLA","o":8.08,"c":8.08,"h":8.08,"l":8.08,"v":8887,"t":"2022-02-17T21:10:00Z","n":3,"vw":8.08}]
# Strated wring to the steam file
# Total Lines in the Strimming file60
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :54
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.100  8.110  8.085    8.086668     8.086684
# 2022-02-17 15:00:00-06:00  8.080  8.110  8.110  8.070    8.095913     8.092054
# 2022-02-17 15:05:00-06:00  8.080  8.080  8.080  8.080         NaN          NaN
# 2022-02-17 15:10:00-06:00  8.080  8.080  8.080  8.080    8.090358     8.090478
# Wrttin  steam file
# messgae received at21:13:00
# [{"T":"b","S":"NKLA","o":8.11,"c":8.11,"h":8.11,"l":8.11,"v":1000,"t":"2022-02-17T21:12:00Z","n":2,"vw":8.11}]
# Strated wring to the steam file
# Total Lines in the Strimming file61
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :55
#                             Open  Close   High    Low  9EMAClosed  21EMAClosed
# TimeStamp
# 2022-02-17 14:20:00-06:00  8.075  8.085  8.120  8.070    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.085  8.065  8.110  8.060    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.065  8.050  8.085  8.040    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.045  8.090  8.110  8.040    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.095  8.115  8.120  8.075    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.110  8.100  8.135  8.085    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.100  8.085  8.100  8.050    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.085  8.100  8.110  8.085    8.086668     8.086684
# 2022-02-17 15:00:00-06:00  8.080  8.110  8.110  8.070    8.095913     8.092054
# 2022-02-17 15:05:00-06:00  8.080  8.080  8.080  8.080         NaN          NaN
# 2022-02-17 15:10:00-06:00  8.080  8.110  8.110  8.080    8.090358     8.090478
# Wrttin  steam file
# messgae received at21:18:00
# [{"T":"b","S":"NKLA","o":8.1001,"c":8.1,"h":8.1001,"l":8.1,"v":1229,"t":"2022-02-17T21:17:00Z","n":4,"vw":8.100244}]
# Strated wring to the steam file
# Total Lines in the Strimming file62
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :56
#                              Open  Close  ...  9EMAClosed  21EMAClosed
# TimeStamp                                 ...
# 2022-02-17 14:20:00-06:00  8.0750  8.085  ...    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.0850  8.065  ...    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.0650  8.050  ...    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.0450  8.090  ...    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.0950  8.115  ...    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.1100  8.100  ...    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.1000  8.085  ...    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.0850  8.100  ...    8.086668     8.086684
# 2022-02-17 15:00:00-06:00  8.0800  8.110  ...    8.095913     8.092054
# 2022-02-17 15:05:00-06:00  8.0800  8.080  ...         NaN          NaN
# 2022-02-17 15:10:00-06:00  8.0800  8.110  ...    8.090358     8.090478
# 2022-02-17 15:15:00-06:00  8.1001  8.100  ...         NaN          NaN
#
# [12 rows x 6 columns]
# Wrttin  steam file
# messgae received at21:20:00
# [{"T":"b","S":"NKLA","o":8.1,"c":8.1,"h":8.1,"l":8.1,"v":273,"t":"2022-02-17T21:19:00Z","n":5,"vw":8.1}]
# Strated wring to the steam file
# Total Lines in the Strimming file63
# As we have 10 datapoints the calucation for 1 to 5 mins conversion started....
# Total Lines in the unique file is :57
#                              Open  Close  ...  9EMAClosed  21EMAClosed
# TimeStamp                                 ...
# 2022-02-17 14:20:00-06:00  8.0750  8.085  ...    8.080552     8.078834
# 2022-02-17 14:25:00-06:00  8.0850  8.065  ...    8.091146     8.087161
# 2022-02-17 14:30:00-06:00  8.0650  8.050  ...    8.081799     8.083059
# 2022-02-17 14:35:00-06:00  8.0450  8.090  ...    8.067438     8.073718
# 2022-02-17 14:40:00-06:00  8.0950  8.115  ...    8.078188     8.077329
# 2022-02-17 14:45:00-06:00  8.1100  8.100  ...    8.099686     8.089468
# 2022-02-17 14:50:00-06:00  8.1000  8.085  ...    8.093896     8.090762
# 2022-02-17 14:55:00-06:00  8.0850  8.100  ...    8.086668     8.086684
# 2022-02-17 15:00:00-06:00  8.0800  8.110  ...    8.095913     8.092054
# 2022-02-17 15:05:00-06:00  8.0800  8.080  ...         NaN          NaN
# 2022-02-17 15:10:00-06:00  8.0800  8.110  ...    8.090358     8.090478
# 2022-02-17 15:15:00-06:00  8.1001  8.100  ...         NaN          NaN
#
# [12 rows x 6 columns]
# Wrttin  steam file
# False

# %%
#########################Testing 
df = pd.read_csv('/content/drive//MyDrive/AlpecaTrading/DataFiles/StreamFiles/{}.csv'.format(ticket_interested),skiprows=3,header=None,index_col=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10 non-null     object
#  1   1       10 non-null     object
#  2   2       10 non-null     float64
#  3   3       10 non-null     float64
#  4   4       10 non-null     float64
#  5   5       10 non-null     float64
#  6   6       10 non-null     int64
#  7   7       10 non-null     object
#  8   8       10 non-null     int64
#  9   9       10 non-null     float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 928.0+ bytes

# %%
df.columns =['Message Type', 
                'Symbol', 
                'Open', 
                'Close',
                'High',
                'Low',
                'Volume',
                'TimeStamp',
                'n',
                'vw']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Message Type  10 non-null     object
#  1   Symbol        10 non-null     object
#  2   Open          10 non-null     float64
#  3   Close         10 non-null     float64
#  4   High          10 non-null     float64
#  5   Low           10 non-null     float64
#  6   Volume        10 non-null     int64
#  7   TimeStamp     10 non-null     object
#  8   n             10 non-null     int64
#  9   vw            10 non-null     float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 928.0+ bytes

# %%
df.loc[:,'TimeStamp'] = pd.to_datetime(df['TimeStamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Message Type  10 non-null     object
#  1   Symbol        10 non-null     object
#  2   Open          10 non-null     float64
#  3   Close         10 non-null     float64
#  4   High          10 non-null     float64
#  5   Low           10 non-null     float64
#  6   Volume        10 non-null     int64
#  7   TimeStamp     10 non-null     datetime64[ns, UTC]
#  8   n             10 non-null     int64
#  9   vw            10 non-null     float64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(2), object(2)
# memory usage: 928.0+ bytes

# %%
df_unique=df.drop_duplicates(subset=['TimeStamp']).copy()
df_unique.head(10)
# df_unique.loc[:,'TimeStamp'] = pd.to_datetime(df_unique['TimeStamp'])
# df_unique.set_index('TimeStamp',inplace=True)
# Out:
#   Message Type Symbol    Open  ...                 TimeStamp    n          vw
# 0            b   MSFT  298.94  ... 2022-02-15 18:59:00+00:00  456  298.970346
# 2            b   MSFT  299.01  ... 2022-02-15 19:00:00+00:00  816  299.033441
# 3            b   MSFT  299.09  ... 2022-02-15 19:01:00+00:00  560  298.939871
# 4            b   MSFT  298.94  ... 2022-02-15 19:02:00+00:00  680  298.785090
# 5            b   MSFT  298.81  ... 2022-02-15 19:03:00+00:00  866  298.739768
# 7            b   MSFT  298.71  ... 2022-02-15 19:04:00+00:00  675  298.776884
# 8            b   MSFT  298.85  ... 2022-02-15 19:05:00+00:00  734  298.617803
# 9            b   MSFT  298.59  ... 2022-02-15 19:06:00+00:00  576  298.469432
#
# [8 rows x 10 columns]

# %%
df_unique.loc[:,'TimeStamp'] = pd.to_datetime(df_unique['TimeStamp'])

# %%
df_unique.set_index('TimeStamp',inplace=True)

# %%
df_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8 entries, 2022-02-15 18:59:00+00:00 to 2022-02-15 19:06:00+00:00
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Message Type  8 non-null      object
#  1   Symbol        8 non-null      object
#  2   Open          8 non-null      float64
#  3   Close         8 non-null      float64
#  4   High          8 non-null      float64
#  5   Low           8 non-null      float64
#  6   Volume        8 non-null      int64
#  7   n             8 non-null      int64
#  8   vw            8 non-null      float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 640.0+ bytes

# %%
eastern = pytz.timezone('US/Central')

# %%
df_unique.index = df_unique.index.tz_convert(eastern)

# %%
df_unique
# Out:
#                           Message Type Symbol    Open  ...  Volume    n          vw
# TimeStamp                                              ...
# 2022-02-15 12:59:00-06:00            b   MSFT  298.94  ...   21606  456  298.970346
# 2022-02-15 13:00:00-06:00            b   MSFT  299.01  ...   44096  816  299.033441
# 2022-02-15 13:01:00-06:00            b   MSFT  299.09  ...   30277  560  298.939871
# 2022-02-15 13:02:00-06:00            b   MSFT  298.94  ...   39193  680  298.785090
# 2022-02-15 13:03:00-06:00            b   MSFT  298.81  ...   49387  866  298.739768
# 2022-02-15 13:04:00-06:00            b   MSFT  298.71  ...   40825  675  298.776884
# 2022-02-15 13:05:00-06:00            b   MSFT  298.85  ...   34817  734  298.617803
# 2022-02-15 13:06:00-06:00            b   MSFT  298.59  ...   25911  576  298.469432
#
# [8 rows x 9 columns]

# %%
df_unique.index = df_unique.index.tz_convert(eastern)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-eb835f198ac6> in <module>()
# ----> 1 df_unique.index = df_unique.index.tz_convert(eastern)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/datetimes.py in tz_convert(self, tz)
#     272     @doc(DatetimeArray.tz_convert)
#     273     def tz_convert(self, tz) -> DatetimeIndex:
# --> 274         arr = self._data.tz_convert(tz)
#     275         return type(self)._simple_new(arr, name=self.name)
#     276
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimes.py in tz_convert(self, tz)
#     854             # tz naive, use tz_localize
#     855             raise TypeError(
# --> 856                 "Cannot convert tz-naive timestamps, use tz_localize to localize"
#     857             )
#     858
#
# TypeError: Cannot convert tz-naive timestamps, use tz_localize to localize
