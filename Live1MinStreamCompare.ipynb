# %% [markdown]
# <a href="https://colab.research.google.com/github/paridaabhishek/Alpacatrade/blob/master/Live1MinStreamCompare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install WebSocket
# !pip install websocket-client
# !pip install alpaca-trade-api
# Out:
# Collecting websocket-client
#   Downloading websocket_client-1.2.3-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 857 kB/s
# Installing collected packages: websocket-client
# Successfully installed websocket-client-1.2.3
# Collecting alpaca-trade-api
#   Downloading alpaca_trade_api-1.5.0-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.5 MB/s
# Collecting deprecation==2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (1.2.3)
# Collecting aiohttp==3.7.4
#   Downloading aiohttp-3.7.4-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 31.1 MB/s
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (2.23.0)
# Collecting websockets<10,>=8.0
#   Downloading websockets-9.1-cp37-cp37m-manylinux2010_x86_64.whl (103 kB)
#      |████████████████████████████████| 103 kB 66.5 MB/s
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (1.19.5)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (1.24.3)
# Collecting PyYAML==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 72.1 MB/s
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from alpaca-trade-api) (1.3.5)
# Collecting msgpack==1.0.2
#   Downloading msgpack-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (273 kB)
#      |████████████████████████████████| 273 kB 66.8 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.1 MB/s
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca-trade-api) (3.0.4)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 64.6 MB/s
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca-trade-api) (3.10.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.4->alpaca-trade-api) (21.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation==2.1.0->alpaca-trade-api) (21.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18.1->alpaca-trade-api) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>2->alpaca-trade-api) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>2->alpaca-trade-api) (2021.10.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->deprecation==2.1.0->alpaca-trade-api) (3.0.7)
# Installing collected packages: multidict, yarl, async-timeout, websockets, PyYAML, msgpack, deprecation, aiohttp, alpaca-trade-api
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.3
#     Uninstalling msgpack-1.0.3:
#       Successfully uninstalled msgpack-1.0.3
# Successfully installed PyYAML-5.4.1 aiohttp-3.7.4 alpaca-trade-api-1.5.0 async-timeout-3.0.1 deprecation-2.1.0 msgpack-1.0.2 multidict-6.0.2 websockets-9.1 yarl-1.7.2

# %%
#Import Libreris
import websocket 
import json
from datetime import datetime
import pandas as pd
import numpy as np
from IPython.core.display import JSON

# %%
#Map Google drive
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
ticket_interested = (input('Enter The Stock yo wanted to autotrade')).upper()
print(ticket_interested+ ' Will be autotraded now!! Sitback and enjoy your day!!')

listen_message='{"action":"subscribe","bars":["'+ticket_interested+'"]}'
print(listen_message)
# Out:
# Enter The Stock yo wanted to autotradeaapl
# AAPL Will be autotraded now!! Sitback and enjoy your day!!
# {"action":"subscribe","bars":["AAPL"]}

# %%
#Import Credentials. Kept the credential in the file Cred.py under the dir below for security.
import sys
import os
import glob
print(glob.glob("/content/drive/*"))
os.chdir('/content/drive//MyDrive/AlpecaTrading/Config')
#sys.path.append('/content/drive/AlpecaTrading/Config')
print(os.getcwd())
from  Cred import *
print(API_KEY)
print(SECRET_KEY)
# Out:
# ['/content/drive/MyDrive']
# /content/drive/MyDrive/AlpecaTrading/Config
# PKENE1R5LIQR1J3778D0
# nT8XMPHULWGvTu4jnDJc6UMK2tSyUAc2YS7npTNV

# %%
#Websocket Code
socket = "wss://stream.data.alpaca.markets/v2/sip" #Webscoket given by alpeca for 
#socket = "wss://paper-api.alpaca.markets/stream" #Webscoket given by alpeca for 
#socket = "wss://stream.data.alpaca.markets/v1beta1/crypto"

print(socket.split('/')[-1])

def on_ope_fun(ws):
    print("Opened")
    auth_data = {"action": "auth","key": API_KEY,"secret": SECRET_KEY }  #Key and Secret getting from the Cred file. 
    ws.send(json.dumps(auth_data))
    #listen_message={"action":"subscribe","trades":["BTCUSD"],"quotes":["LTCUSD","ETHUSD"],"bars":["BCHUSD"]}
    #listen_message={"action":"subscribe","trades":["BTCUSD"]}
    #listen_message={"action":"subscribe","bars":["BTCUSD"]}
    listen_message='{"action":"subscribe","bars":["'+ticket_interested+'"]}'
    print(listen_message)
    #listen_message={"action":"subscribe","bars":["AAPL"]}  ### --> Modify based on whatever symbol you want to check
    ws.send(json.dumps(json.loads(listen_message)))


    print('Still Open')

def on_msg_fun(ws,message):
    now = datetime.now()
    current_time = now.strftime("%H:%M:%S")
    print("messgae received at"+ current_time)
    print(message)
    print('Strated wring to the steam file')
    testBarWithTradingView(message)
    print('Wrttin  steam file')

def on_clg_fun(ws):
    print("Closed")
# Out:
# sip

# %%
def testBarWithTradingView(message):
  messageJson = json.loads(message)
  df = pd.DataFrame(messageJson)
  df.to_csv('/content/drive//MyDrive/AlpecaTrading/DataFiles/StreamFiles/{}.csv'.format(ticket_interested),mode='a', index=False, header=False)

# %%
ws = websocket.WebSocketApp(socket, on_open=on_ope_fun,on_message=on_msg_fun)
ws.run_forever()
# Out:
# Opened
# {"action":"subscribe","bars":["AAPL"]}
# Still Open
# messgae received at18:06:00
# [{"T":"success","msg":"connected"}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:06:01
# [{"T":"success","msg":"authenticated"}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:06:01
# [{"T":"subscription","trades":[],"quotes":[],"bars":["AAPL"],"dailyBars":[],"statuses":[],"lulds":[],"corrections":[],"cancelErrors":[]}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:07:00
# [{"T":"b","S":"AAPL","o":175.76,"c":175.835,"h":175.835,"l":175.76,"v":84912,"t":"2022-02-09T18:06:00Z","n":882,"vw":175.797779}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:08:00
# [{"T":"b","S":"AAPL","o":175.8382,"c":175.82,"h":175.895,"l":175.81,"v":115797,"t":"2022-02-09T18:07:00Z","n":1026,"vw":175.850576}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:09:00
# [{"T":"b","S":"AAPL","o":175.8399,"c":175.765,"h":175.8399,"l":175.73,"v":79518,"t":"2022-02-09T18:08:00Z","n":791,"vw":175.768989}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:09:30
# [{"T":"b","S":"AAPL","o":175.8399,"c":175.765,"h":175.8399,"l":175.73,"v":79519,"t":"2022-02-09T18:08:00Z","n":792,"vw":175.768989}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:10:00
# [{"T":"b","S":"AAPL","o":175.77,"c":175.78,"h":175.795,"l":175.71,"v":58859,"t":"2022-02-09T18:09:00Z","n":604,"vw":175.749417}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:11:00
# [{"T":"b","S":"AAPL","o":175.78,"c":175.738,"h":175.8199,"l":175.73,"v":52793,"t":"2022-02-09T18:10:00Z","n":631,"vw":175.770492}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:12:00
# [{"T":"b","S":"AAPL","o":175.74,"c":175.7,"h":175.75,"l":175.682,"v":63403,"t":"2022-02-09T18:11:00Z","n":604,"vw":175.714599}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:12:30
# [{"T":"b","S":"AAPL","o":175.74,"c":175.7,"h":175.75,"l":175.682,"v":63404,"t":"2022-02-09T18:11:00Z","n":605,"vw":175.714598}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:13:00
# [{"T":"b","S":"AAPL","o":175.715,"c":175.6672,"h":175.715,"l":175.6301,"v":55400,"t":"2022-02-09T18:12:00Z","n":670,"vw":175.669357}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:14:00
# [{"T":"b","S":"AAPL","o":175.66,"c":175.62,"h":175.68,"l":175.61,"v":56872,"t":"2022-02-09T18:13:00Z","n":687,"vw":175.652095}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:15:00
# [{"T":"b","S":"AAPL","o":175.6269,"c":175.6401,"h":175.7,"l":175.58,"v":107621,"t":"2022-02-09T18:14:00Z","n":999,"vw":175.644005}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:16:00
# [{"T":"b","S":"AAPL","o":175.65,"c":175.6799,"h":175.71,"l":175.63,"v":69921,"t":"2022-02-09T18:15:00Z","n":864,"vw":175.676913}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:17:00
# [{"T":"b","S":"AAPL","o":175.68,"c":175.7001,"h":175.715,"l":175.6414,"v":64440,"t":"2022-02-09T18:16:00Z","n":858,"vw":175.686794}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:18:00
# [{"T":"b","S":"AAPL","o":175.7013,"c":175.655,"h":175.7088,"l":175.615,"v":53787,"t":"2022-02-09T18:17:00Z","n":613,"vw":175.658366}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:18:30
# [{"T":"b","S":"AAPL","o":175.7013,"c":175.655,"h":175.7088,"l":175.615,"v":53788,"t":"2022-02-09T18:17:00Z","n":614,"vw":175.658366}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:19:00
# [{"T":"b","S":"AAPL","o":175.67,"c":175.76,"h":175.77,"l":175.665,"v":80470,"t":"2022-02-09T18:18:00Z","n":801,"vw":175.723186}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:20:00
# [{"T":"b","S":"AAPL","o":175.756,"c":175.69,"h":175.756,"l":175.68,"v":45530,"t":"2022-02-09T18:19:00Z","n":504,"vw":175.719511}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:21:00
# [{"T":"b","S":"AAPL","o":175.69,"c":175.75,"h":175.75,"l":175.65,"v":89385,"t":"2022-02-09T18:20:00Z","n":933,"vw":175.70511}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:22:00
# [{"T":"b","S":"AAPL","o":175.76,"c":175.7267,"h":175.8,"l":175.7124,"v":98146,"t":"2022-02-09T18:21:00Z","n":875,"vw":175.771683}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:23:00
# [{"T":"b","S":"AAPL","o":175.7287,"c":175.695,"h":175.74,"l":175.69,"v":52614,"t":"2022-02-09T18:22:00Z","n":590,"vw":175.710542}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:23:30
# [{"T":"b","S":"AAPL","o":175.7287,"c":175.695,"h":175.74,"l":175.69,"v":52615,"t":"2022-02-09T18:22:00Z","n":591,"vw":175.710542}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:24:00
# [{"T":"b","S":"AAPL","o":175.7,"c":175.7,"h":175.71,"l":175.68,"v":33912,"t":"2022-02-09T18:23:00Z","n":486,"vw":175.69733}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:25:00
# [{"T":"b","S":"AAPL","o":175.7017,"c":175.61,"h":175.72,"l":175.57,"v":115733,"t":"2022-02-09T18:24:00Z","n":1032,"vw":175.635159}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:26:00
# [{"T":"b","S":"AAPL","o":175.62,"c":175.6199,"h":175.665,"l":175.61,"v":60204,"t":"2022-02-09T18:25:00Z","n":650,"vw":175.638957}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:27:00
# [{"T":"b","S":"AAPL","o":175.615,"c":175.662,"h":175.6699,"l":175.57,"v":67449,"t":"2022-02-09T18:26:00Z","n":674,"vw":175.63387}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:28:00
# [{"T":"b","S":"AAPL","o":175.665,"c":175.61,"h":175.69,"l":175.6078,"v":60933,"t":"2022-02-09T18:27:00Z","n":745,"vw":175.663278}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:29:00
# [{"T":"b","S":"AAPL","o":175.61,"c":175.5909,"h":175.635,"l":175.58,"v":89283,"t":"2022-02-09T18:28:00Z","n":679,"vw":175.602107}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:30:00
# [{"T":"b","S":"AAPL","o":175.6,"c":175.62,"h":175.645,"l":175.585,"v":62117,"t":"2022-02-09T18:29:00Z","n":655,"vw":175.615675}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:31:00
# [{"T":"b","S":"AAPL","o":175.63,"c":175.68,"h":175.6875,"l":175.57,"v":78648,"t":"2022-02-09T18:30:00Z","n":730,"vw":175.633861}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:31:30
# [{"T":"b","S":"AAPL","o":175.63,"c":175.68,"h":175.6875,"l":175.57,"v":78652,"t":"2022-02-09T18:30:00Z","n":731,"vw":175.633864}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:32:00
# [{"T":"b","S":"AAPL","o":175.6799,"c":175.6899,"h":175.72,"l":175.66,"v":91532,"t":"2022-02-09T18:31:00Z","n":827,"vw":175.694389}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:33:00
# [{"T":"b","S":"AAPL","o":175.6801,"c":175.64,"h":175.6801,"l":175.64,"v":35917,"t":"2022-02-09T18:32:00Z","n":504,"vw":175.66728}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:34:00
# [{"T":"b","S":"AAPL","o":175.63,"c":175.6,"h":175.6478,"l":175.58,"v":87767,"t":"2022-02-09T18:33:00Z","n":739,"vw":175.611168}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:35:00
# [{"T":"b","S":"AAPL","o":175.59,"c":175.6268,"h":175.6301,"l":175.58,"v":67116,"t":"2022-02-09T18:34:00Z","n":582,"vw":175.607941}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:35:30
# [{"T":"b","S":"AAPL","o":175.59,"c":175.6268,"h":175.6301,"l":175.58,"v":67117,"t":"2022-02-09T18:34:00Z","n":583,"vw":175.607941}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:36:00
# [{"T":"b","S":"AAPL","o":175.6227,"c":175.605,"h":175.625,"l":175.55,"v":175490,"t":"2022-02-09T18:35:00Z","n":1667,"vw":175.591682}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:37:00
# [{"T":"b","S":"AAPL","o":175.61,"c":175.6592,"h":175.67,"l":175.605,"v":83526,"t":"2022-02-09T18:36:00Z","n":696,"vw":175.641591}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:37:30
# [{"T":"b","S":"AAPL","o":175.61,"c":175.6592,"h":175.67,"l":175.605,"v":83571,"t":"2022-02-09T18:36:00Z","n":697,"vw":175.641598}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:38:00
# [{"T":"b","S":"AAPL","o":175.655,"c":175.685,"h":175.705,"l":175.65,"v":76470,"t":"2022-02-09T18:37:00Z","n":756,"vw":175.680758}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:39:00
# [{"T":"b","S":"AAPL","o":175.68,"c":175.62,"h":175.69,"l":175.595,"v":89116,"t":"2022-02-09T18:38:00Z","n":815,"vw":175.642168}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:40:00
# [{"T":"b","S":"AAPL","o":175.615,"c":175.57,"h":175.6382,"l":175.56,"v":62422,"t":"2022-02-09T18:39:00Z","n":669,"vw":175.596096}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:41:00
# [{"T":"b","S":"AAPL","o":175.565,"c":175.58,"h":175.62,"l":175.54,"v":87023,"t":"2022-02-09T18:40:00Z","n":766,"vw":175.577775}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:42:00
# [{"T":"b","S":"AAPL","o":175.5876,"c":175.605,"h":175.64,"l":175.585,"v":49812,"t":"2022-02-09T18:41:00Z","n":555,"vw":175.606346}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:43:00
# [{"T":"b","S":"AAPL","o":175.6,"c":175.61,"h":175.625,"l":175.59,"v":30501,"t":"2022-02-09T18:42:00Z","n":483,"vw":175.607115}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:44:00
# [{"T":"b","S":"AAPL","o":175.615,"c":175.64,"h":175.68,"l":175.61,"v":72608,"t":"2022-02-09T18:43:00Z","n":584,"vw":175.6526}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:44:30
# [{"T":"b","S":"AAPL","o":175.615,"c":175.64,"h":175.68,"l":175.61,"v":72609,"t":"2022-02-09T18:43:00Z","n":585,"vw":175.6526}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:45:00
# [{"T":"b","S":"AAPL","o":175.65,"c":175.735,"h":175.735,"l":175.645,"v":103457,"t":"2022-02-09T18:44:00Z","n":798,"vw":175.697321}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:46:00
# [{"T":"b","S":"AAPL","o":175.7399,"c":175.7,"h":175.7399,"l":175.6702,"v":86645,"t":"2022-02-09T18:45:00Z","n":801,"vw":175.702468}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:47:00
# [{"T":"b","S":"AAPL","o":175.6974,"c":175.82,"h":175.83,"l":175.69,"v":159598,"t":"2022-02-09T18:46:00Z","n":1172,"vw":175.775767}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:48:00
# [{"T":"b","S":"AAPL","o":175.82,"c":175.75,"h":175.82,"l":175.73,"v":72563,"t":"2022-02-09T18:47:00Z","n":826,"vw":175.775185}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:49:00
# [{"T":"b","S":"AAPL","o":175.75,"c":175.7701,"h":175.7701,"l":175.71,"v":46367,"t":"2022-02-09T18:48:00Z","n":588,"vw":175.740079}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:50:00
# [{"T":"b","S":"AAPL","o":175.77,"c":175.715,"h":175.79,"l":175.715,"v":42093,"t":"2022-02-09T18:49:00Z","n":554,"vw":175.753598}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:51:00
# [{"T":"b","S":"AAPL","o":175.715,"c":175.695,"h":175.727,"l":175.67,"v":50897,"t":"2022-02-09T18:50:00Z","n":670,"vw":175.699425}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:52:00
# [{"T":"b","S":"AAPL","o":175.69,"c":175.632,"h":175.69,"l":175.63,"v":72722,"t":"2022-02-09T18:51:00Z","n":754,"vw":175.663962}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:53:00
# [{"T":"b","S":"AAPL","o":175.63,"c":175.6082,"h":175.6478,"l":175.5799,"v":106240,"t":"2022-02-09T18:52:00Z","n":814,"vw":175.605679}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:54:00
# [{"T":"b","S":"AAPL","o":175.6,"c":175.575,"h":175.62,"l":175.5428,"v":94641,"t":"2022-02-09T18:53:00Z","n":821,"vw":175.579621}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:55:00
# [{"T":"b","S":"AAPL","o":175.58,"c":175.58,"h":175.6,"l":175.5439,"v":60700,"t":"2022-02-09T18:54:00Z","n":700,"vw":175.571552}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:56:00
# [{"T":"b","S":"AAPL","o":175.58,"c":175.61,"h":175.62,"l":175.57,"v":70852,"t":"2022-02-09T18:55:00Z","n":699,"vw":175.598666}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:57:00
# [{"T":"b","S":"AAPL","o":175.61,"c":175.555,"h":175.62,"l":175.555,"v":79771,"t":"2022-02-09T18:56:00Z","n":809,"vw":175.585356}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:58:00
# [{"T":"b","S":"AAPL","o":175.555,"c":175.5598,"h":175.56,"l":175.435,"v":158434,"t":"2022-02-09T18:57:00Z","n":1315,"vw":175.508107}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at18:59:00
# [{"T":"b","S":"AAPL","o":175.5608,"c":175.513,"h":175.57,"l":175.51,"v":67754,"t":"2022-02-09T18:58:00Z","n":598,"vw":175.542894}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:00:00
# [{"T":"b","S":"AAPL","o":175.515,"c":175.6,"h":175.62,"l":175.5032,"v":76793,"t":"2022-02-09T18:59:00Z","n":789,"vw":175.567721}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:01:00
# [{"T":"b","S":"AAPL","o":175.6091,"c":175.68,"h":175.69,"l":175.59,"v":119352,"t":"2022-02-09T19:00:00Z","n":1012,"vw":175.655558}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:01:30
# [{"T":"b","S":"AAPL","o":175.6091,"c":175.68,"h":175.69,"l":175.59,"v":119353,"t":"2022-02-09T19:00:00Z","n":1013,"vw":175.655558}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:02:00
# [{"T":"b","S":"AAPL","o":175.68,"c":175.7,"h":175.72,"l":175.6312,"v":103145,"t":"2022-02-09T19:01:00Z","n":751,"vw":175.685749}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:03:00
# [{"T":"b","S":"AAPL","o":175.6901,"c":175.72,"h":175.76,"l":175.6901,"v":88279,"t":"2022-02-09T19:02:00Z","n":867,"vw":175.734433}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:04:00
# [{"T":"b","S":"AAPL","o":175.73,"c":175.765,"h":175.79,"l":175.7245,"v":72827,"t":"2022-02-09T19:03:00Z","n":713,"vw":175.760308}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:04:30
# [{"T":"b","S":"AAPL","o":175.73,"c":175.7663,"h":175.79,"l":175.7245,"v":73127,"t":"2022-02-09T19:03:00Z","n":714,"vw":175.760333}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:05:00
# [{"T":"b","S":"AAPL","o":175.7691,"c":175.7004,"h":175.78,"l":175.69,"v":87673,"t":"2022-02-09T19:04:00Z","n":924,"vw":175.739533}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:06:00
# [{"T":"b","S":"AAPL","o":175.71,"c":175.72,"h":175.73,"l":175.6999,"v":59171,"t":"2022-02-09T19:05:00Z","n":694,"vw":175.715947}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:07:00
# [{"T":"b","S":"AAPL","o":175.7201,"c":175.79,"h":175.85,"l":175.715,"v":128084,"t":"2022-02-09T19:06:00Z","n":1314,"vw":175.797991}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:08:00
# [{"T":"b","S":"AAPL","o":175.7824,"c":175.86,"h":175.87,"l":175.7824,"v":74355,"t":"2022-02-09T19:07:00Z","n":728,"vw":175.836797}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:09:00
# [{"T":"b","S":"AAPL","o":175.865,"c":175.97,"h":175.97,"l":175.8528,"v":146719,"t":"2022-02-09T19:08:00Z","n":1076,"vw":175.912206}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:10:00
# [{"T":"b","S":"AAPL","o":175.965,"c":175.995,"h":176,"l":175.94,"v":110118,"t":"2022-02-09T19:09:00Z","n":1133,"vw":175.97179}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:11:00
# [{"T":"b","S":"AAPL","o":175.9972,"c":175.961,"h":176.05,"l":175.9601,"v":261584,"t":"2022-02-09T19:10:00Z","n":2375,"vw":176.005322}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:12:00
# [{"T":"b","S":"AAPL","o":175.9658,"c":175.905,"h":175.99,"l":175.9001,"v":92637,"t":"2022-02-09T19:11:00Z","n":995,"vw":175.940028}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:13:00
# [{"T":"b","S":"AAPL","o":175.902,"c":175.9372,"h":175.94,"l":175.84,"v":71703,"t":"2022-02-09T19:12:00Z","n":808,"vw":175.888}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:14:00
# [{"T":"b","S":"AAPL","o":175.9343,"c":175.95,"h":176,"l":175.93,"v":110179,"t":"2022-02-09T19:13:00Z","n":964,"vw":175.968987}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:15:00
# [{"T":"b","S":"AAPL","o":175.94,"c":175.903,"h":175.99,"l":175.869,"v":77729,"t":"2022-02-09T19:14:00Z","n":865,"vw":175.913552}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:16:00
# [{"T":"b","S":"AAPL","o":175.9,"c":175.85,"h":175.9068,"l":175.84,"v":72276,"t":"2022-02-09T19:15:00Z","n":801,"vw":175.867625}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:17:00
# [{"T":"b","S":"AAPL","o":175.855,"c":175.8741,"h":175.89,"l":175.85,"v":180215,"t":"2022-02-09T19:16:00Z","n":526,"vw":175.798858}]
# Strated wring to the steam file
# Wrttin  steam file
# messgae received at19:18:00
# [{"T":"b","S":"AAPL","o":175.875,"c":175.835,"h":175.9,"l":175.811,"v":50794,"t":"2022-02-09T19:17:00Z","n":611,"vw":175.84797}]
# Strated wring to the steam file
# Wrttin  steam file
# False

# %% [markdown]
# #Testing COnclusion . Tested it for AAPL manually , by checking the trading view . Its all working fine ![AAPL.JPG](data:image/jpeg;base64,...)
